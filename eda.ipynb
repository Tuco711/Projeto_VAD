# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Covid Dataset

# %%
import pandas as pd

try:
    df = pd.read_csv('datasets/full_grouped.csv')

except FileNotFoundError:
    df = pd.read_csv('/content/drive/MyDrive/Universidade/Mestrado/2 Semestre/Visualização e Análise de Dados/Projeto/Projeto_VAD/datasets/owid-covid-data.csv')

df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# population                                   int64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %%
df.min(numeric_only=True)
# Out:
# total_cases                                    0.00
# new_cases                                      0.00
# new_cases_smoothed                             0.00
# total_deaths                                   0.00
# new_deaths                                     0.00
#                                              ...
# population                                    47.00
# excess_mortality_cumulative_absolute      -37726.10
# excess_mortality_cumulative                  -44.23
# excess_mortality                             -95.92
# excess_mortality_cumulative_per_million    -2936.45
# Length: 62, dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# total_cases                                7.758668e+08
# new_cases                                  4.423623e+07
# new_cases_smoothed                         6.319461e+06
# total_deaths                               7.057132e+06
# new_deaths                                 1.037190e+05
#                                                ...
# population                                 7.975105e+09
# excess_mortality_cumulative_absolute       1.349776e+06
# excess_mortality_cumulative                7.808000e+01
# excess_mortality                           3.782200e+02
# excess_mortality_cumulative_per_million    1.029352e+04
# Length: 62, dtype: float64

# %% [markdown]
# # GDP Dataset
