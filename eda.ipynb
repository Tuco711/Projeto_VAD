# %%
import pandas as pd

df = pd.read_csv('/content/full_grouped.csv')

print(len(df.columns))
[print(col) for col in df.columns]
# Out:
# 10
# Date
# Country/Region
# Confirmed
# Deaths
# Recovered
# Active
# New cases
# New deaths
# New recovered
# WHO Region
# [None, None, None, None, None, None, None, None, None, None]

# %%
df['Deaths'].groupby(df['WHO Region'])
